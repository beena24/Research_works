# %% [markdown]
# <a href="https://colab.research.google.com/github/beena24/Research_works/blob/main/glrlm_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import numpy as np
data=pd.read_csv('/content/drive/MyDrive/GLRLM_final.csv',na_filter='False')
data.fillna(0)

# %%
data1=data.drop(data.columns[np.isnan(data).any()], axis=1)

# %%
np.where(data.values >= np.finfo(np.float64).max)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
print(np.isnan(data1))

# %%
y=data1.class_label
x=data1.drop('class_label',axis=1)

# %%
x_test.tail()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.tail()
# Out:
#       d0.00g0_SR0.00  d0.00g45_SR0.00  d0.00g90_SR0.00  d0.00g135_SR0.00  \
# 5115        0.907047         0.924101         0.900384          0.923664
# 2381        0.876909         0.892673         0.851941          0.890692
# 7237        0.858336         0.872462         0.831482          0.867210
# 4069        0.881939         0.900375         0.834293          0.890497
# 1596        0.874196         0.901200         0.873443          0.901755
#
#       d0.00g0_LR0.00  d0.00g45_LR0.00  d0.00g90_LR0.00  d0.00g135_LR0.00  \
# 5115       10.747054         7.109179        28.740733          6.983087
# 2381        1.817090         1.613127         2.057105          1.628218
# 7237        2.930625         2.536985        12.622705          2.737662
# 4069        1.845070         1.596019         2.426993          1.677273
# 1596        2.615607         2.010681         3.858219          2.053668
#
#       d0.00g0_GLN  d0.00g45_GLN  ...  d0.00g90_SRHGL0.00  d0.00g135_SRHGL0.00  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import calibration_curve
# Create classifiers
lr = LogisticRegression(max_iter=10000)
#gnb = GaussianNB()
#log_reg = LogisticRegression(solver='lbfgs',class_weight='balanced', max_iter=10000)
from sklearn.preprocessing import RobustScaler
#scaler = RobustScaler()
#x = scaler.fit_transfrom(x)
from sklearn import preprocessing
#x_test = preprocessing.scale(x_test)
svc = LinearSVC(C=1.0, max_iter=5000)
rfc = RandomForestClassifier()

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
LR_Model = lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
SVC_Model = svc.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
RFC_Model = rfc.fit(x_train, y_train)

# %%
import pickle

with open('LR_model.pkl', 'wb') as f1:
    pickle.dump(LR_Model,f1)
    f1.close()


with open('SVM_model.pkl', 'wb') as f3:
    pickle.dump(SVC_Model,f3)
    f3.close()
with open('RFC_model.pkl', 'wb') as f4:
    pickle.dump(RFC_Model,f4)
    f4.close()

# %%
from IPython.display import FileLink

FileLink(r'LR_model.pkl')
# Out:
# /content/LR_model.pkl

# %%
FileLink(r'SVM_model.pkl')
# Out:
# /content/SVM_model.pkl

# %%
FileLink(r'RFC_model.pkl')
# Out:
# /content/RFC_model.pkl

# %%
from sklearn.metrics import accuracy_score


#LR_y_pred = LR_Model.predict(x_test)
#GNB_y_pred = GNB_Model.predict(x_test)
SVC_y_pred = SVC_Model.predict(x_test)

# %%
RFC_y_pred=RFC_Model.predict(x_test)

# %%
LR_acc_sc = accuracy_score(y_test, LR_y_pred)
LR_acc_sc

# %%
SVC_acc_sc = accuracy_score(y_test, SVC_y_pred)
SVC_acc_sc
# Out:
# 0.7943573667711599

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
cm_plot_labels = ['normal','covid','bacterial','viral']

# %%
import itertools

# %%
cm_svc = confusion_matrix(y_test, SVC_y_pred)
plot_confusion_matrix(cm=cm_svc, classes=cm_plot_labels, title='SVM Confusion Matrix')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
RFC_acc_sc=accuracy_score(y_test,RFC_y_pred)
RFC_acc_sc
# Out:
# 0.8996865203761756

# %%
#print('LogisticRegression score: %f' % LR_Model.score(x_test, y_test))
#print('Naive Bayes score: %f' % GNB_Model.score(x_test, y_test))
print('SVM score: %f' % SVC_Model.score(x_test, y_test))
print('RFC score:%f' % RFC_Model.score(x_test,y_test))
# Out:
# SVM score: 0.794357
# RFC score:0.899687

# %%
import xgboost as xgb

# %%
xgb_classifier = xgb.XGBClassifier()

# %%
XGB_Model=xgb_classifier.fit(x_train,y_train)

# %%
with open('XGB_Model.pkl', 'wb') as f5:
    pickle.dump(XGB_Model,f5)
    f5.close()

# %%
from IPython.display import FileLink

FileLink(r'XGB_Model.pkl')
# Out:
# /content/XGB_Model.pkl

# %%
XGB_y_pred=XGB_Model.predict(x_test)

# %%
XGB_acc_sc = accuracy_score(y_test, XGB_y_pred)
XGB_acc_sc
# Out:
# 0.9203761755485893

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier()
LGBM_Model=clf.fit(x_train, y_train)

# %%
with open('LGBM_Model.pkl', 'wb') as f6:
    pickle.dump(LGBM_Model,f6)
    f6.close()

# %%
from IPython.display import FileLink

FileLink(r'LGBM_Model.pkl')
# Out:
# /content/LGBM_Model.pkl

# %%
LGBM_y_pred=LGBM_Model.predict(x_test)

# %%
LGBM_acc_sc = accuracy_score(y_test, LGBM_y_pred)
LGBM_acc_sc
# Out:
# 0.9191222570532915

# %%
cm_lgbm = confusion_matrix(y_test, LGBM_y_pred)
plot_confusion_matrix(cm=cm_lgbm, classes=cm_plot_labels, title='LGBM Confusion Matrix')

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()
k.fit(x_train,y_train)
result=k.predict(x_test)
print(accuracy_score(y_test,result))
# Out:
# 0.8338557993730408

# %%
cm_knn = confusion_matrix(y_test, result)
plot_confusion_matrix(cm=cm_knn, classes=cm_plot_labels, title='KNN Confusion Matrix')

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()
d.fit(x_train,y_train)
y_pred=d.predict(x_test)

print(accuracy_score(y_test,y_pred))
# Out:
# 0.8470219435736677

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)

print(accuracy_score(y_test,y_pred))
# Out:
# 0.8884012539184953

# %%
import matplotlib.pyplot as plt

# %%
def plot_confusion_matrix(cm, classes, normalize=False,title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    plt.figure(figsize=(8,8), dpi=100)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    savefilename = title+'.jpeg'

    plt.savefig(savefilename)

# %%
cm_xgb = confusion_matrix(y_test, XGB_y_pred)
plot_confusion_matrix(cm=cm_xgb, classes=cm_plot_labels, title='XGB Confusion Matrix')
