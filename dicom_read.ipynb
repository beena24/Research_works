# %% [markdown]
# <a href="https://colab.research.google.com/github/beena24/Research_works/blob/main/dicom_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import *
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data_path = "/content/drive/MyDrive/dicom_dir/"
#output_path = working_path = "/C:/Users/Acer/Desktop/"
g = glob(data_path + '/*.dcm')

# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d DICOM images.\nFirst 10 filenames:" % len(g))
print('\n'.join(g[:20]))
# Out:
# Total of 100 DICOM images.
# First 10 filenames:
# /content/drive/MyDrive/dicom_dir/ID_0002_AGE_0074_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0004_AGE_0056_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0001_AGE_0069_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0003_AGE_0075_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0000_AGE_0060_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0013_AGE_0060_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0021_AGE_0067_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0011_AGE_0061_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0015_AGE_0061_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0010_AGE_0060_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0012_AGE_0061_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0016_AGE_0063_CONTRAST_1_CT.dcm
# /content/drive/MyDrive/dicom_dir/ID_0019_AGE_0070_CONTRAST_1_CT.dcm
# ...

# %%
pip install pydicom

# %%
import matplotlib.pyplot as plt
import pydicom
import pydicom.data
base = r"/content/drive/MyDrive/dicom_dir/"
pass_dicom = "ID_0000_AGE_0060_CONTRAST_1_CT.dcm"
filename = pydicom.data.data_manager.get_files(base, pass_dicom)[0]
ds = pydicom.dcmread(filename)
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)  # set the color map to bone
plt.show()

# %%
from pydicom import dcmread

# %%
src = "/content/drive/MyDrive/dicom_dir/"
dst = "/C:/Users/Acer/Desktop/new"

print('reading file list...')
unsortedList = []
for root, dirs, files in os.walk(src):
    for file in files:
        if ".dcm" in file:
            unsortedList.append(os.path.join(root, file))

print('%s files found.' % len(unsortedList))
# Out:
# reading file list...
# 100 files found.

# %%
path ="/content/drive/MyDrive/dicom_dir/"
patient_dicom = load_scan(path)
patient_pixels = get_pixels_hu(patient_dicom)
print(patient_pixels)
#sanity check
plt.imshow(patient_pixels[50], cmap=plt.cm.bone)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0adddb7ce792> in <module>()
#       1 path ="/content/drive/MyDrive/dicom_dir/"
# ----> 2 patient_dicom = load_scan(path)
#       3 patient_pixels = get_pixels_hu(patient_dicom)
#       4 print(patient_pixels)
#       5 #sanity check
#
# NameError: name 'load_scan' is not defined

# %%
import copy

# %%
pip install dicom
# Out:
# ...
#      |████████████████████████████████| 766 kB 4.3 MB/s
# ...

# %%
import pydicom as dicom
path1="/content/drive/MyDrive/dicom_dir/ID_0002_AGE_0074_CONTRAST_1_CT.dcm"
x=dicom.dcmread(path1)
print(dir(x))
# Out:
# ['AccessionNumber', 'AcquisitionDate', 'AcquisitionNumber', 'AcquisitionTime', 'BitsAllocated', 'BitsStored', 'BodyPartExamined', 'CTDIvol', 'Columns', 'ContentDate', 'ContentTime', 'ContrastBolusAgent', 'ContrastBolusIngredientConcentration', 'ContrastBolusVolume', 'ContrastFlowDuration', 'ContrastFlowRate', 'ConvolutionKernel', 'DataCollectionDiameter', 'DateOfLastCalibration', 'DeidentificationMethod', 'DeidentificationMethodCodeSequence', 'DerivationCodeSequence', 'DerivationDescription', 'DeviceSerialNumber', 'DistanceSourceToDetector', 'DistanceSourceToPatient', 'EstimatedDoseSaving', 'Exposure', 'ExposureModulationType', 'ExposureTime', 'FilterType', 'FocalSpots', 'FrameOfReferenceUID', 'GantryDetectorTilt', 'GeneratorPower', 'HighBit', 'ImageComments', 'ImageOrientationPatient', 'ImagePositionPatient', 'ImageType', 'InstanceNumber', 'KVP', 'LargestImagePixelValue', 'LongitudinalTemporalInformationModified', 'LossyImageCompression', 'LossyImageCompressionMethod', 'LossyImageCo
# ...

# %%
print(x.pixel_array)
# Out:
# [[ 25  18  24 ...  53  60  62]
#  [ 19  15  22 ...  30  36  38]
#  [ 19  13  14 ...  28  30  26]
#  ...
#  [507 568 595 ... 386 399 446]
#  [397 428 473 ... 461 569 681]
#  [470 403 377 ... 729 858 972]]
